# %%
class Node:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data
------------------------------------------------------
class Node1:
    def __init__(self, data):
        self.data = data+1
------------------------------------------------------
from Node import Node
from Node import Node1

a = [3, 5, 4, 1, 2]

root = None #3
for i in a:
    if root == None:
        # add root
        node = Node(i) #3
        root = node #3
    else:
        if type(point) is Node:
            point = root #3
            while True:
                if point.data <= i:
                    if point.right is not None:
                        point = point.right
                    else: # point.right is None, right position
                        node = Node(i)
                        point.right = node
                        break
                else:
                    if point.left is not None:
                        point = point.left
                    else:
                        node = Node(i)
                        point.left = node
                        break
        elif type(point) is Node1:
            break
            
                        
# recursive function
def put(root, b):
    # 1 step
    if root.left:
        put(root.left, b)
    
    # 2 step
    b.append(root.data)
    
    # 3 step
    if root.right:
        put(root.right, b)
    

b = []
put(root, b)
print(b)
